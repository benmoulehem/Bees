# %% [markdown]
# # **Data Understanding**

# %%
import numpy as np
import pandas as pd
from pathlib import Path

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import tensorflow as tf

from sklearn.metrics import confusion_matrix, classification_report
# Out:
# 2024-05-02 11:22:11.315833: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-02 11:22:11.315928: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-02 11:22:11.451482: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# **Data Source 1 :**

# %%
df = pd.read_csv("/kaggle/input/honey-bee-pollen/PollenDataset/pollen_data.csv")
df.head()
# Out:
#    Unnamed: 0          filename  pollen_carrying
# 0           0   P10057-125r.jpg                1
# 1           1   P57380-120r.jpg                1
# 2           2  NP63671-221r.jpg                0
# 3           3   NP53776-47r.jpg                0
# 4           4  NP13382-201r.jpg                0

# %% [markdown]
# Our dataset is composed of two major components: an images directory containing images of bees, some with pollen and some without, and a CSV file containing two labels: the filename of the images and the pollen_carrying label that indicates whether the bee has pollen or not (1 for pollen presence and 0 for pollen absence).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       714 non-null    int64
#  1   filename         714 non-null    object
#  2   pollen_carrying  714 non-null    int64
# dtypes: int64(2), object(1)
# memory usage: 16.9+ KB

# %%
df['pollen_carrying'] = df['pollen_carrying'].map({0: "No Pollen", 1: "Pollen"})

# %% [markdown]
# To convert integers into a string.

# %%
print(df.groupby('pollen_carrying').size())
# Out:
# pollen_carrying
# No Pollen    345
# Pollen       369
# dtype: int64

# %%
image_path = '../input/honey-bee-pollen/PollenDataset/images/'
df['filename'] = df['filename'].apply(lambda x: image_path / Path(x)).astype(str)

# %% [markdown]
# The data that we are working with is balanced; the number of bees carrying pollen and the number of bees that don't are very close, so there's no need for data augmentation at the moment.

# %% [markdown]
# **Data Source 2 :**

# %%
df2 = pd.read_csv("/kaggle/input/honey-bee-annotated-images/bee_data.csv")
df2.head()
# Out:
#           file     date   time        location  zip code subspecies  \
# 0  041_066.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 1  041_072.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 2  041_073.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 3  041_067.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
# 4  041_059.png  8/28/18  16:07  Alvin, TX, USA     77511         -1
#
#               health  pollen_carrying   caste
# 0  hive being robbed            False  worker
# 1  hive being robbed            False  worker
# 2  hive being robbed            False  worker
# 3  hive being robbed            False  worker
# 4  hive being robbed            False  worker

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5172 entries, 0 to 5171
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   file             5172 non-null   object
#  1   date             5172 non-null   object
#  2   time             5172 non-null   object
#  3   location         5172 non-null   object
#  4   zip code         5172 non-null   int64
#  5   subspecies       5172 non-null   object
#  6   health           5172 non-null   object
#  7   pollen_carrying  5172 non-null   bool
#  8   caste            5172 non-null   object
# dtypes: bool(1), int64(1), object(7)
# memory usage: 328.4+ KB

# %%
print(df2.groupby('pollen_carrying').size())
# Out:
# pollen_carrying
# False    5154
# True       18
# dtype: int64

# %%
cols = ['file','pollen_carrying']
df2 = df2[cols]

# %%
df2 = df2.rename(columns={'file': 'filename'})

# %%
random_False = df2[df2['pollen_carrying'] == False].sample(n=40, random_state=42)

True_rows = df2[df2['pollen_carrying'] == True]

result = pd.concat([random_False, True_rows])

# Shuffle the DataFrame
result = result.sample(frac=1, random_state=42).reset_index(drop=True)

result['pollen_carrying'] = result['pollen_carrying'].astype(int)

result['pollen_carrying'] = result['pollen_carrying'].map({0: "No Pollen", 1: "Pollen"})

df2=result

image_path = '../kaggle/input/honey-bee-annotated-images/bee_imgs/bee_imgs/'
df2['filename'] = df2['filename'].apply(lambda x: image_path / Path(x)).astype(str)

df2.head(40)
# Out:
#                                              filename pollen_carrying
# 0   ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 1   ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 2   ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 3   ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 4   ../kaggle/input/honey-bee-annotated-images/bee...          Pollen
# 5   ../kaggle/input/honey-bee-annotated-images/bee...          Pollen
# 6   ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 7   ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 8   ../kaggle/input/honey-bee-annotated-images/bee...          Pollen
# 9   ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 10  ../kaggle/input/honey-bee-annotated-images/bee...          Pollen
# 11  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 12  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 13  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 14  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 15  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 16  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 17  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 18  ../kaggle/input/honey-bee-annotated-images/bee...          Pollen
# 19  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 20  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 21  ../kaggle/input/honey-bee-annotated-images/bee...          Pollen
# 22  ../kaggle/input/honey-bee-annotated-images/bee...          Pollen
# 23  ../kaggle/input/honey-bee-annotated-images/bee...          Pollen
# 24  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 25  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 26  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 27  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 28  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 29  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 30  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 31  ../kaggle/input/honey-bee-annotated-images/bee...          Pollen
# 32  ../kaggle/input/honey-bee-annotated-images/bee...          Pollen
# 33  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 34  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 35  ../kaggle/input/honey-bee-annotated-images/bee...          Pollen
# 36  ../kaggle/input/honey-bee-annotated-images/bee...          Pollen
# 37  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen
# 38  ../kaggle/input/honey-bee-annotated-images/bee...          Pollen
# 39  ../kaggle/input/honey-bee-annotated-images/bee...       No Pollen

# %%
print(df2.groupby('pollen_carrying').size())
# Out:
# pollen_carrying
# No Pollen    40
# Pollen       18
# dtype: int64

# %% [markdown]
# Now we have a new CSV file that contains 40 non-carrying pollen images and 18 carrying pollen ones.

# %%
df.head(40)
# Out:
#     Unnamed: 0                                           filename  \
# 0            0  ../input/honey-bee-pollen/PollenDataset/images...
# 1            1  ../input/honey-bee-pollen/PollenDataset/images...
# 2            2  ../input/honey-bee-pollen/PollenDataset/images...
# 3            3  ../input/honey-bee-pollen/PollenDataset/images...
# 4            4  ../input/honey-bee-pollen/PollenDataset/images...
# 5            5  ../input/honey-bee-pollen/PollenDataset/images...
# 6            6  ../input/honey-bee-pollen/PollenDataset/images...
# 7            7  ../input/honey-bee-pollen/PollenDataset/images...
# 8            8  ../input/honey-bee-pollen/PollenDataset/images...
# 9            9  ../input/honey-bee-pollen/PollenDataset/images...
# 10          10  ../input/honey-bee-pollen/PollenDataset/images...
# 11          11  ../input/honey-bee-pollen/PollenDataset/images...
# 12          12  ../input/honey-bee-pollen/PollenDataset/images...
# 13          13  ../input/honey-bee-pollen/PollenDataset/images...
# 14          14  ../input/honey-bee-pollen/PollenDataset/images...
# 15          15  ../input/honey-bee-pollen/PollenDataset/images...
# 16          16  ../input/honey-bee-pollen/PollenDataset/images...
# 17          17  ../input/honey-bee-pollen/PollenDataset/images...
# 18          18  ../input/honey-bee-pollen/PollenDataset/images...
# 19          19  ../input/honey-bee-pollen/PollenDataset/images...
# 20          20  ../input/honey-bee-pollen/PollenDataset/images...
# 21          21  ../input/honey-bee-pollen/PollenDataset/images...
# 22          22  ../input/honey-bee-pollen/PollenDataset/images...
# 23          23  ../input/honey-bee-pollen/PollenDataset/images...
# 24          24  ../input/honey-bee-pollen/PollenDataset/images...
# 25          25  ../input/honey-bee-pollen/PollenDataset/images...
# 26          26  ../input/honey-bee-pollen/PollenDataset/images...
# 27          27  ../input/honey-bee-pollen/PollenDataset/images...
# 28          28  ../input/honey-bee-pollen/PollenDataset/images...
# 29          29  ../input/honey-bee-pollen/PollenDataset/images...
# 30          30  ../input/honey-bee-pollen/PollenDataset/images...
# 31          31  ../input/honey-bee-pollen/PollenDataset/images...
# 32          32  ../input/honey-bee-pollen/PollenDataset/images...
# 33          33  ../input/honey-bee-pollen/PollenDataset/images...
# 34          34  ../input/honey-bee-pollen/PollenDataset/images...
# 35          35  ../input/honey-bee-pollen/PollenDataset/images...
# 36          36  ../input/honey-bee-pollen/PollenDataset/images...
# 37          37  ../input/honey-bee-pollen/PollenDataset/images...
# 38          38  ../input/honey-bee-pollen/PollenDataset/images...
# 39          39  ../input/honey-bee-pollen/PollenDataset/images...
#
#    pollen_carrying
# 0           Pollen
# 1           Pollen
# 2        No Pollen
# 3        No Pollen
# 4        No Pollen
# 5           Pollen
# 6           Pollen
# 7        No Pollen
# 8        No Pollen
# 9           Pollen
# 10       No Pollen
# 11          Pollen
# 12          Pollen
# 13       No Pollen
# 14          Pollen
# 15          Pollen
# 16          Pollen
# 17          Pollen
# 18          Pollen
# 19       No Pollen
# 20          Pollen
# 21          Pollen
# 22       No Pollen
# 23          Pollen
# 24          Pollen
# 25          Pollen
# 26          Pollen
# 27          Pollen
# 28       No Pollen
# 29          Pollen
# 30       No Pollen
# 31       No Pollen
# 32          Pollen
# 33          Pollen
# 34       No Pollen
# 35          Pollen
# 36       No Pollen
# 37          Pollen
# 38          Pollen
# 39          Pollen

# %%
print(df.size)
# Out:
# 2142

# %% [markdown]
# # Data Preparation

# %% [markdown]
# First we need to transform filnames into the images paths

# %%
 df_train, df_test = train_test_split(df, train_size=0.8, shuffle=True, random_state=0)

# %% [markdown]
# In the previous cell, we aimed to split our dataset into training and testing datasets. Setting the shuffle parameter to true means that the data will be taken randomly (without the need for a random_state)

# %%
# Create training generator
train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    rotation_range=45,
    width_shift_range=0.05,
    height_shift_range=0.05,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.5, 1.5],
    channel_shift_range=100,  # Adjust this value based on the desired intensity of the yellow color
    validation_split=0.2
)


# Create test generator
test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255
)

# %% [markdown]
# channel_shift_range is set to 100, which means that the values of the red and green channels will be randomly shifted by up to 100 intensity levels. This will emphasize the yellow color in the images by increasing the intensity of the red and green channels, as yellow is a combination of red and green light

# %% [markdown]
# We are going to work on data generators, which are part of TensorFlow's Keras API. This method helps us load and preprocess large datasets. Our dataset consists of 700 images, which can sometimes be large.
#
# **Note: There is no need for rotation in the preprocessing for the moment, as the images are already in the correct orientation.**

# %% [markdown]
# Now we can flow the images from the generators with the paths.

# %%
train_images = train_generator.flow_from_dataframe(
    dataframe=df_train,
    x_col='filename',
    y_col='pollen_carrying',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='training'
)
val_images = train_generator.flow_from_dataframe(
    dataframe=df_train,
    x_col='filename',
    y_col='pollen_carrying',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=True,
    seed=42,
    subset='validation'
)
test_images = test_generator.flow_from_dataframe(
    dataframe=df_test,
    x_col='filename',
    y_col='pollen_carrying',
    target_size=(224, 224),
    color_mode='rgb',
    class_mode='binary',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 457 validated image filenames belonging to 2 classes.
# Found 114 validated image filenames belonging to 2 classes.
# Found 143 validated image filenames belonging to 2 classes.

# %% [markdown]
# **Important points**
#
# * DataFrame: The source dataset.
# * class_mode: Classification mode (usually set to binary when it's a 2-item classification).
# * batch_size: The size of the batches of data.
# * shuffle: When set to one, it ensures that the samples are randomly taken.
# * seed: The random seed.
# * subset: The use case of the generated data.

# %% [markdown]
# # Display images

# %% [markdown]
# We need to understand the shape and the type of images

# %%
train_images[0][0].shape
# Out:
# (32, 224, 224, 3)

# %% [markdown]
# * The 32 reffers to the size of the batch .
# * The 224,224 reffers to the size of images (224 x 224 pixels ).
# * The 3 reffers to 3 layers , 3 channels (RGB)

# %%
plt.figure(figsize=(12,6))

for i in range(8):
    plt.subplot(1, 8, i+1)
    plt.imshow(train_images[0][0][i+12])
    plt.title("No Pollen" if test_images.labels[i+12] == 0 else "Pollen")
    plt.axis('off')
    
plt.show()

# %% [markdown]
# # Training

# %% [markdown]
# * The pollen sacks can be really small or out of the frame depending on the picture. This might result in prediction errors.
# * We are going to create a Convolutional Neural Network .
# * The images will be doing **filtering** and **pooling** until the number of features are reduced.
# * The classification is then made by a standard neural network.

# %% [markdown]
# ![cv.PNG](attachment:1449c6a9-6a41-45be-ad40-09f994bf7545.PNG)

# %% [markdown]
# **Extract the features**

# %%
inputs = tf.keras.Input(shape=(224, 224, 3))
x = tf.keras.layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu')(inputs)
x = tf.keras.layers.MaxPool2D(pool_size=(2, 2))(x)
x = tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu')(x)
x = tf.keras.layers.MaxPool2D(pool_size=(2, 2))(x)
x = tf.keras.layers.GlobalAveragePooling2D()(x)

# %% [markdown]
# * Layer 1 : Filter with Conv2D layers and detect with relu activation.
# * Layer 2 : Condense with MaxPool2D.( reduces the number of features by losing information)
# * Layer 3 : Same as layer 1 but with more filters to extract more features.
# * Layer 4 : condense with MaxPool2D.
# * Layer 5 :Global Average Pooling reduces the features to 1D by taking the average over the first two dimensions of each 32 filters.

# %% [markdown]
# **Classifie (standard neural network)**

# %%
x = tf.keras.layers.Dense(128, activation='relu')(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x
E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49290: 6.83391, expected 5.89635
# 2024-05-02 11:28:06.136910: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49291: 6.48434, expected 5.54679
# 2024-05-02 11:28:06.136918: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49292: 7.11584, expected 6.17829
# 2024-05-02 11:28:06.136926: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49293: 7.09259, expected 6.15504
# 2024-05-02 11:28:06.136933: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49294: 6.44395, expected 5.50639
# 2024-05-02 11:28:06.136941: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49295: 5.42748, expected 4.48993
# 2024-05-02 11:28:06.136948: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49296: 6.02837, expected 5.09081
# 2024-05-02 11:28:06.142363: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[15,16,222,222]{3,2,1,0}, u8[0]{0}) custom-call(f32[15,3,224,224]{3,2,1,0}, f32[16,3,3,3]{3,2,1,0}, f32[16]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-02 11:28:06.142393: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-02 11:28:06.142406: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-02 11:28:06.142413: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-02 11:28:06.142420: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-02 11:28:06.142434: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-05-02 11:28:06.307707: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49286: 7.99239, expected 7.05484
# 2024-05-02 11:28:06.307771: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49287: 7.67291, expected 6.73536
# 2024-05-02 11:28:06.307780: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49288: 7.80895, expected 6.8714
# 2024-05-02 11:28:06.307788: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49290: 6.83391, expected 5.89635
# 2024-05-02 11:28:06.307796: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49291: 6.48434, expected 5.54679
# 2024-05-02 11:28:06.307821: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49292: 7.11584, expected 6.17829
# 2024-05-02 11:28:06.307829: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49293: 7.09259, expected 6.15504
# 2024-05-02 11:28:06.307837: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49294: 6.44395, expected 5.50639
# 2024-05-02 11:28:06.307845: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49295: 5.42748, expected 4.48993
# 2024-05-02 11:28:06.307853: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 49296: 6.02837, expected 5.09081
# 2024-05-02 11:28:06.313084: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[15,16,222,222]{3,2,1,0}, u8[0]{0}) custom-call(f32[15,3,224,224]{3,2,1,0}, f32[16,3,3,3]{3,2,1,0}, f32[16]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-05-02 11:28:06.313114: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-05-02 11:28:06.313123: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-05-02 11:28:06.313130: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-05-02 11:28:06.313137: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-05-02 11:28:06.313152: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# Accuracy: 69.93 %

# %% [markdown]
# Our model gives us good results with new data . There is no overfiting .

# %% [markdown]
# For more evaluation of our model , we will explore the confusion matrix , the Classification Report

# %%
predictions = np.squeeze(model.predict(test_images) >= 0.5).astype(int)
cm = confusion_matrix(test_images.labels, predictions, labels=[0, 1])
clr = classification_report(test_images.labels, predictions, labels=[0, 1], target_names=["No Pollen", "Pollen"])
# Display
plt.figure(figsize=(4, 4))

sns.heatmap(cm, annot=True, fmt='g', vmin=0, cmap='Reds', cbar=False)
plt.xticks(ticks=[0.5, 1.5], labels=["No Pollen", "Pollen"])
plt.yticks(ticks=[0.5, 1.5], labels=["No Pollen", "Pollen"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.show()

print("Classification Report:\n----------------------\n", clr)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#    No Pollen       0.68      0.74      0.71        70
#       Pollen       0.73      0.66      0.69        73
#
#     accuracy                           0.70       143
#    macro avg       0.70      0.70      0.70       143
# weighted avg       0.70      0.70      0.70       143

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['accuracy', 'val_accuracy']].plot();

# %% [markdown]
# The learning curves in this model stayed close together for much longer. This suggests that the augmentation helped prevent overfitting, allowing the model to continue improving.
